# %%
import geopandas as gpd
import sys
sys.path.append( '../cartagen4py/algorithms/points' )
from cartagen4py.algorithms.points.label_grid_oop import LabelGrid

# %% [markdown]
# # Parameters

# %%
puntos = gpd.read_file('./data/puntos/puntos3.shp')
width = 10

# %%
puntos
# Out:
#     value       geometry
# 0       3  POINT (93 89)
# 1       1  POINT (79 85)
# 2       3  POINT (82 90)
# 3       7  POINT (90 94)
# 4      10  POINT (86 85)
# 5       9  POINT (93 92)
# 6       7  POINT (87 94)
# 7       5  POINT (85 85)
# 8       1  POINT (80 94)
# 9      10  POINT (78 81)
# 10      4  POINT (92 89)
# 11      3  POINT (77 91)
# 12      7  POINT (89 97)
# 13     10  POINT (89 97)
# 14      8  POINT (80 87)
# 15     10  POINT (89 90)
# 16      1  POINT (92 83)
# 17      2  POINT (79 93)
# 18      8  POINT (89 90)
# 19      5  POINT (90 96)
# 20     10  POINT (20 59)
# 21      8  POINT (15 66)
# 22      9  POINT (18 69)
# 23      7  POINT (23 60)
# 24      8  POINT (17 70)
# 25     10  POINT (16 58)
# 26      1  POINT (12 64)
# 27      7  POINT (20 62)
# 28      1  POINT (25 63)
# 29      2   POINT (8 68)
# 30      4  POINT (22 70)
# 31      3  POINT (11 68)
# 32      6  POINT (18 61)
# 33      2  POINT (11 69)
# 34      4  POINT (14 62)
# 35      2  POINT (11 64)
# 36      3   POINT (9 73)
# 37      7  POINT (16 58)
# 38      1  POINT (24 66)
# 39      4  POINT (14 58)
# 40      6  POINT (86 50)
# 41      6  POINT (79 39)
# 42      5  POINT (85 46)
# 43      4  POINT (85 35)
# 44      7  POINT (84 51)
# 45      4  POINT (76 50)
# 46      9  POINT (79 42)
# 47     10  POINT (85 39)
# 48      8  POINT (77 40)
# 49      2  POINT (82 43)
# 50      6  POINT (76 38)
# 51      7  POINT (77 36)
# 52      5  POINT (88 48)
# 53     10  POINT (87 50)
# 54      8  POINT (78 42)
# 55      7  POINT (80 45)
# 56      9  POINT (84 48)
# 57      2  POINT (72 42)
# 58      4  POINT (87 42)
# 59      1  POINT (89 40)

# %% [markdown]
# # Create and set Label Grid object

# %%
lg = LabelGrid(puntos, width, width, "hexagonal")
lg.set_point_label_grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 lg = LabelGrid(puntos, width, value, "hexagonal")
#       2 lg.set_point_label_grid()
#
# NameError: name 'value' is not defined

# %% [markdown]
# ## Draw the result

# %%
lg.draw()

# %% [markdown]
# ### Square cells grid

# %%
lg = LabelGrid(puntos, width, width, "square")
lg.set_point_label_grid()
lg.draw()

# %%
lg = LabelGrid(puntos, width, width, "diamond")
lg.set_point_label_grid()
lg.draw()
